# %%
import numpy as np
from LinearRegressionModel import LinearRegressionModel

# %%
# load the data

data = np.genfromtxt('data/univariateData.dat',
                     delimiter=',')

X = data[:,0]
Y = data[:,1]
X =np.reshape(X ,(len(Y),1))
Y =np.reshape(Y ,(len(Y),1))

# %%
model = LinearRegressionModel()

# %%
model.fit(X,Y,0.003,3000)

# %%
model.plot_cost_versus_iteration()
# Out:
# [8.47991069 6.77837559 6.25630455 ... 4.68595261 4.68594279 4.68593299]

# %%
model.plot_model_over_data()
# Out:
# [1.     5.8918]

# %%
model.evaluate_performance()
# Out:
# 'R_squard error is : 0.828155387694844'
