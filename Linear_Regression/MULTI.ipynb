# %%
import numpy as np
from LinearRegressionModel import LinearRegressionModel

# %%
data = np.genfromtxt('data/multivariateData.dat',
                     delimiter=',')

X = data[:,0:2]
Y = data[:,2]
X =np.reshape(X ,(len(Y),2))
Y =np.reshape(Y ,(len(Y),1))

# %%
model = LinearRegressionModel()

# %%
model.fit(X,Y,10**-11*1.7,20000)

# %%
model.plot_cost_versus_iteration()

# %%
model.plot_model_over_data()

# %%
model.evaluate_performance()
# Out:
# 'R_squard error is : 0.18441542615130824'
